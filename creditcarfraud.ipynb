# %% [markdown]
# <a href="https://colab.research.google.com/github/ojhabineet/Credit-Card-Fraud-Detection/blob/main/creditcarfraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('/content/creditcard.csv')

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
import numpy as np

mask = y.notna()
X = X.loc[mask]
y = y.loc[mask]

X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1191
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           1.00      1192
#    macro avg       0.50      0.50      0.50      1192
# weighted avg       1.00      1.00      1.00      1192
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
sample = X_test.sample(5, random_state=42)
sample_pred = model.predict(sample)

for i, pred in enumerate(sample_pred):
    print(f"Transaction {i+1} =>", "FraUD" if pred == 1 else "Normal")
# Out:
# Transaction 1 => Normal
# Transaction 2 => Normal
# Transaction 3 => Normal
# Transaction 4 => Normal
# Transaction 5 => Normal
